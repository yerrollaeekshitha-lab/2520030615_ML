# %% [markdown]
# <a href="https://colab.research.google.com/github/yerrollaeekshitha-lab/2520030615_ML/blob/main/Practical/WEEK_1_PYTHON_LAB_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns
from pandas import read_csv
df=read_csv('/content/placement_predict_50k Dataset (1).csv')

# %%
#Displays the last five records of the dataset.
df.tail(5)
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49996      49997    Male  Bangalore       Tier2          EE             AI
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
# 49999      50000  Female      Delhi       Tier2         ECE     Networking
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  \
# 49995     No                No       7.84       8.45  ...               2
# 49996     No                No       6.08       6.12  ...               3
# 49997    Yes               Yes       5.69       6.09  ...               2
# 49998     No                No       6.02       6.31  ...               2
# 49999     No                No       6.51       6.37  ...               0
#
#        Publications  AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 49995             1               75.8               3.9             54.2
# 49996             2               81.4               3.8             56.1
# 49997             0                NaN               3.1             49.1
# 49998             1               74.5               2.5              NaN
# 49999             0               58.3               2.3             29.5
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 49995                 NaN                0       High                1
# 49996                67.7                0        Low                1
# 49997                57.7                1        Low                0
# 49998                48.3                1        Low                0
# 49999                30.6                0        Low                0
#
#        IsAnomaly
# 49995          0
# 49996          0
# 49997          0
# 49998          0
# 49999          0
#
# [5 rows x 31 columns]

# %%
df['StudentID']
df.shape
# Out:
# (50000, 31)

# %%
df.dtypes
# Out:
# StudentID               int64
# Gender                 object
# City                   object
# CollegeTier            object
# Stream                 object
# Specialisation         object
# Hostel                 object
# HistoryOfBacklogs      object
# SGPA_Sem1             float64
# SGPA_Sem2             float64
# SGPA_Sem3             float64
# SGPA_Sem4             float64
# SGPA_Sem5             float64
# SGPA_Sem6             float64
# SGPA_Sem7             float64
# SGPA_Sem8             float64
# CGPA                  float64
# AttendancePercent     float64
# Internships             int64
# Projects                int64
# Workshops             float64
# Certifications          int64
# Publications            int64
# AptitudeTestScore     float64
# SoftSkillsRating      float64
# CodingTestScore       float64
# MockInterviewScore    float64
# ExtraCurricular         int64
# CGPA_Tier              object
# PlacementStatus         int64
# IsAnomaly               int64
# dtype: object

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})
missing_data
# Out:
#                     Missing Values  Percentage
# StudentID                        0       0.000
# Gender                           0       0.000
# City                             0       0.000
# CollegeTier                      0       0.000
# Stream                           0       0.000
# Specialisation                   0       0.000
# Hostel                           0       0.000
# HistoryOfBacklogs                0       0.000
# SGPA_Sem1                        0       0.000
# SGPA_Sem2                        0       0.000
# SGPA_Sem3                        0       0.000
# SGPA_Sem4                        0       0.000
# SGPA_Sem5                        0       0.000
# SGPA_Sem6                        0       0.000
# SGPA_Sem7                        0       0.000
# SGPA_Sem8                        0       0.000
# CGPA                             0       0.000
# AttendancePercent                0       0.000
# Internships                      0       0.000
# Projects                         0       0.000
# Workshops                     4488       8.976
# Certifications                   0       0.000
# Publications                     0       0.000
# AptitudeTestScore             4029       8.058
# SoftSkillsRating              3526       7.052
# CodingTestScore               2976       5.952
# MockInterviewScore            4957       9.914
# ExtraCurricular                  0       0.000
# CGPA_Tier                        0       0.000
# PlacementStatus                  0       0.000
# IsAnomaly                        0       0.000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
#Keeps the first occurrence and marks subsequent duplicates as True(if any)
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [StudentID, Gender, City, CollegeTier, Stream, Specialisation, Hostel, HistoryOfBacklogs, SGPA_Sem1, SGPA_Sem2, SGPA_Sem3, SGPA_Sem4, SGPA_Sem5, SGPA_Sem6, SGPA_Sem7, SGPA_Sem8, CGPA, AttendancePercent, Internships, Projects, Workshops, Certifications, Publications, AptitudeTestScore, SoftSkillsRating, CodingTestScore, MockInterviewScore, ExtraCurricular, CGPA_Tier, PlacementStatus, IsAnomaly]
# Index: []
#
# [0 rows x 31 columns]
# ----------------------------------------

# %%
#display rows where null values are present if any
df[df['AptitudeTestScore'].isnull()]
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 7              8    Male      Delhi       Tier2  Mechanical       Embedded
# 13            14    Male      Delhi       Tier1          CS             AI
# 18            19    Male  Bangalore       Tier2  Mechanical       Embedded
# 29            30  Female       Pune       Tier2       Civil     Networking
# 33            34    Male      Kochi       Tier3       Civil             AI
# ...          ...     ...        ...         ...         ...            ...
# 49935      49936    Male  Bangalore       Tier3         ECE       Embedded
# 49943      49944    Male     Jaipur       Tier3          CS    DataScience
# 49947      49948  Female  Bangalore       Tier1          CS     Networking
# 49961      49962    Male      Delhi       Tier2          CS    DataScience
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  \
# 7        Yes                No       5.87       5.64  ...               0
# 13        No                No      10.00      10.00  ...               3
# 18        No                No       6.97       6.53  ...               1
# 29       Yes                No       9.94       9.85  ...               3
# 33       Yes                No       4.52       4.06  ...               1
# ...      ...               ...        ...        ...  ...             ...
# 49935     No                No       5.73       5.73  ...               0
# 49943     No               Yes       5.28       5.53  ...               0
# 49947     No                No       9.75      10.00  ...               4
# 49961    Yes                No       7.10       7.00  ...               3
# 49997    Yes               Yes       5.69       6.09  ...               2
#
#        Publications  AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 7                 0                NaN               2.0             35.2
# 13                1                NaN               NaN             87.9
# 18                0                NaN               1.3             57.9
# 29                2                NaN               4.8             60.3
# 33                1                NaN               2.1             27.4
# ...             ...                ...               ...              ...
# 49935             1                NaN               2.0             28.6
# 49943             0                NaN               NaN              NaN
# 49947             1                NaN               4.2             55.6
# 49961             2                NaN               NaN             98.5
# 49997             0                NaN               3.1             49.1
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 7                    27.8                0        Low                0
# 13                   86.8                1       High                1
# 18                   56.6                0        Mid                0
# 29                   89.3                1       High                1
# 33                   34.6                1        Low                0
# ...                   ...              ...        ...              ...
# 49935                32.5                0        Low                0
# 49943                26.0                0        Low                0
# 49947                63.1                1       High                1
# 49961                75.7                1        Mid                1
# 49997                57.7                1        Low                0
#
#        IsAnomaly
# 7              0
# 13             0
# 18             0
# 29             0
# 33             0
# ...          ...
# 49935          0
# 49943          0
# 49947          0
# 49961          0
# 49997          0
#
# [4029 rows x 31 columns]

# %%
df.describe()
# Out:
#           StudentID     SGPA_Sem1     SGPA_Sem2     SGPA_Sem3     SGPA_Sem4  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   25000.500000      7.210583      7.222243      7.235398      7.247290
# std    14433.901067      1.517846      1.532008      1.551632      1.570629
# min        1.000000      4.000000      4.000000      4.000000      4.000000
# 25%    12500.750000      6.090000      6.090000      6.080000      6.070000
# 50%    25000.500000      7.190000      7.210000      7.220000      7.240000
# 75%    37500.250000      8.340000      8.360000      8.400000      8.430000
# max    50000.000000     10.000000     10.000000     10.000000     10.000000
#
#           SGPA_Sem5     SGPA_Sem6     SGPA_Sem7     SGPA_Sem8          CGPA  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       7.258639      7.274511      7.282720      7.293704      7.246154
# std        1.587829      1.603261      1.621605      1.638112      1.615686
# min        4.000000      4.000000      4.000000      4.000000      4.000000
# 25%        6.070000      6.080000      6.060000      6.060000      6.040000
# 50%        7.260000      7.280000      7.300000      7.310000      7.250000
# 75%        8.460000      8.500000      8.520000      8.560000      8.480000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...     Workshops  Certifications  Publications  AptitudeTestScore  \
# count  ...  45512.000000    50000.000000  50000.000000       45971.000000
# mean   ...      1.804469        1.931420      0.735460          68.859261
# std    ...      1.036193        1.175391      0.717167          15.365230
# min    ...      0.000000        0.000000      0.000000          30.000000
# 25%    ...      1.000000        1.000000      0.000000          58.500000
# 50%    ...      2.000000        2.000000      1.000000          69.900000
# 75%    ...      3.000000        3.000000      1.000000          79.700000
# max    ...      4.000000        5.000000      3.000000         100.000000
#
#        SoftSkillsRating  CodingTestScore  MockInterviewScore  ExtraCurricular  \
# count      46474.000000     47024.000000         45043.00000     50000.000000
# mean           3.154211        57.411273            55.40853         0.533000
# std            0.981333        20.979679            17.52218         0.498915
# min            1.000000         0.000000            15.90000         0.000000
# 25%            2.400000        45.900000            44.20000         0.000000
# 50%            3.200000        57.700000            54.70000         1.000000
# 75%            3.900000        73.300000            69.20000         1.000000
# max            5.000000       100.000000           100.00000         1.000000
#
#        PlacementStatus     IsAnomaly
# count     50000.000000  50000.000000
# mean          0.657120      0.035000
# std           0.474677      0.183782
# min           0.000000      0.000000
# 25%           0.000000      0.000000
# 50%           1.000000      0.000000
# 75%           1.000000      0.000000
# max           1.000000      1.000000
#
# [8 rows x 23 columns]
