# %% [markdown]
# <a href="https://colab.research.google.com/github/yerrollaeekshitha-lab/2520030615_ML/blob/main/Practical/python_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types.
x = 5
y = 3.14
name = "CGPA"
is_placed = True

print(x)
print(type(x))
print(y)
print(type(y))
print(name)
print(type(name))
print(is_placed)
print(type(is_placed))
# Out:
# 5
# <class 'int'>
# 3.14
# <class 'float'>
# CGPA
# <class 'str'>
# True
# <class 'bool'>

# %%
# ---ARITHMETIC OPERATORS ---
a = 7
b = 2
print("a + b", a + b)
print("a - b", a - b)
print("a * b", a * b)
print("a / b", a / b)
print("a % b", a % b)
print("a ** 2", a ** 2)
print("a // b", a // b)

# --- COMPARISION OPERATIONS ---
cgpa = 8.4
print("cgpa > 8 :", cgpa > 8)
print("cgpa < 8 :", cgpa < 8)
print("cgpa >= 8 :", cgpa >= 8)
print("cgpa < 8 :", cgpa <= 8)
print("cgpa == 8 :", cgpa == 8)
print("cgpa != 8 :", cgpa != 8)

# --- LOGICAL OPERATORS: and / or / not ---
attendance = 85
placed = (cgpa > 85) and (attendance > 80)
print("placed:", placed)
placed = (cgpa > 85) or (attendance > 80)
print("placed:", placed)
placed = not (cgpa > 85)
print("placed:", placed)

#
# Out:
# a + b 9
# a - b 5
# a * b 14
# a / b 3.5
# a % b 1
# a ** 2 49
# a // b 3
# cgpa > 8 : True
# cgpa < 8 : False
# cgpa >= 8 : True
# cgpa < 8 : False
# cgpa == 8 : False
# cgpa != 8 : True
# placed: False
# placed: True
# placed: True

# %%
# -- f string --
model_name = "Logistic Regression"
accuracy = 0.13408

# Old, clunky way (avoid this):
print("Accuracy of " + model_name + " is " + str(accuracy))

# f-string way (use this):
print(f"Accuracy of {model_name} is {accuracy}")

# ':.3f' inside the braces rounds a float to 3 decimal places -
# you will use this in almost every experiment to print clean metrics.
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.13408
# Accuracy of Logistic Regression is 0.13408
# Accuracy of Logistic Regression is 0.134

# %%
# --- LISTS & INDEXING ---

features = ["CGPA", "AptitudeTestScore", "CodingTestScore", "MockInterviewScore"]

print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))

# Slicing:
print(features[0:2])

# Adding to a list
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore']
# CGPA
# AptitudeTestScore
# MockInterviewScore
# 4
# ['CGPA', 'AptitudeTestScore']
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore', 'Internships']
