# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
df = pd.read_csv("/content/Titanic-Dataset.csv")

print("Dataset Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (891, 12)
#
# Columns:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
y = df["PassengerId"]

# %%
PassengerId = [
    "Survived",
    "Age",
    "Pclass",
    "Name",
    "Sex",
    "SibSp",
    "Parch",
    "Ticket",
    "Fare"
]

X = df[PassengerId].copy()

# %%
categorical_features = [
    "ocean_proximity"
]

# %%
numerical_features = [
    "longitude",
    "latitude",
    "housing_median_age",
    "total_rooms",
    "total_bedrooms",
    "population",
    "households",
    "median_income"
]

# %%
# Redefine numerical and categorical features for the Titanic dataset's X DataFrame
# 'Age' is a numerical feature with missing values in the Titanic dataset.
# 'Fare', 'SibSp', 'Parch' are also numerical, although usually without missing values.
# 'Sex', 'Pclass' are categorical features in X. Other categorical columns like 'Name' and 'Ticket'
# are typically handled differently or do not have missing values.
numerical_features = ['Age', 'SibSp', 'Parch', 'Fare']
categorical_features = ['Sex', 'Pclass'] # Only considering these for general imputation; 'Name' and 'Ticket' typically don't have NaNs and need specific handling.

for col in numerical_features:
    if col in X.columns:
        X[col] = X[col].fillna(X[col].median())

for col in categorical_features:
    if col in X.columns:
        X[col] = X[col].fillna(X[col].mode()[0])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
preprocessor = ColumnTransformer(
    transformers=[

        (
            "num",
            StandardScaler(),
            numerical_features
        ),

        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore",
                drop="first"
            ),
            categorical_features
        )
    ]
)

# %%
linear_model = Pipeline(
    steps=[

        ("preprocessor", preprocessor),

        (
            "regressor",
            LinearRegression()
        )
    ]
)

# %%
linear_model.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age', 'SibSp', 'Parch',
#                                                    'Fare']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Sex', 'Pclass'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = linear_model.predict(X_test)

# %%
mae = mean_absolute_error(
    y_test,
    y_pred
)

mse = mean_squared_error(
    y_test,
    y_pred
)

rmse = np.sqrt(mse)

r2 = r2_score(
    y_test,
    y_pred
)


print("\n============================================")
print("LINEAR REGRESSION RESULTS")
print("============================================")

print("\nMean Absolute Error (MAE):")
print(round(mae, 4))

print("\nMean Squared Error (MSE):")
print(round(mse, 4))

print("\nRoot Mean Squared Error (RMSE):")
print(round(rmse, 4))

print("\nR² Score:")
print(round(r2, 4))
# Out:
# ...
# LINEAR REGRESSION RESULTS
# ...
#
# Mean Absolute Error (MAE):
# 224.3947
#
# Mean Squared Error (MSE):
# 68080.6851
#
# Root Mean Squared Error (RMSE):
# 260.9228
#
# R² Score:
# -0.0101
